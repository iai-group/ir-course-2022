# %% [markdown]
# # Clarifying questions
#
# This demo is based on ClariQ code available [here](https://github.com/aliannejadi/ClariQ).
#
# ClariQ dataset aims to study the following situation for dialogue settings:
#   * a user is asking an ambiguous question (where ambiguous question is a question to which one can return > 1 possible answers)
#   * the system must identify that the question is ambiguous, and, instead of trying to answer it directly, ask a good clarifying question
#
# ClariQ was collected as part of the [ConvAI3](http://convai.io) challenge which was co-organized with the [SCAI workshop](https://scai-workshop.github.io/2020/). The collected dataset consists of:
#
#
# 1.   **User Request**: an initial user request in the conversational form, e.g., "What is Fickle Creek Farm?", with a label reflects if clarification is needed ranged from 1 to 4;
# 2.   **Clarification questions**: a set of possible clarifying questions, e.g., "Do you want to know the location of fickle creek farm?";
# 3.   **User Answers**: each questions is supplied with a user answer, e.g., "No, I want to find out where can i purchase fickle creek farm products."
#
#
# For training, the collected dataset is split into training (187 topics) and validation (50 topics) sets. For testing, the participants are supplied with: (1) a set of user requests in conversational form and (2) a set of questions (i.e., question bank) which contains all the questions that we have collected for the collection. Therefore there are the following two tasks:
#
# 1.   Given a user request, return a score [1−4] indicating the necessity of asking clarifying questions.
# 2.   Given a user request which needs clarification, return the most suitable clarifying question. Here participants are able to choose:
#       * either select the clarifying question from the provided question bank (all clarifying questions we collected), aiming to maximize the precision,
#       * or choose not to ask any question (by choosing Q0001 from the question bank.)
#
# In this notebook we investigate the BM25 ranker being a simple baseline model. It ranks the questions simply by their BM25 relevance score compared to the original_request.

# %%
# Installs required packages & clones ClariQ repo.

! pip install rank_bm25
! git clone https://github.com/aliannejadi/ClariQ.git ClariQ-repo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rank_bm25
#   Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from rank_bm25) (1.21.6)
# Installing collected packages: rank-bm25
# Successfully installed rank-bm25-0.2.2
# Cloning into 'ClariQ-repo'...
# remote: Enumerating objects: 210, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 210 (delta 14), reused 34 (delta 14), pack-reused 176
# Receiving objects: 100% (210/210), 253.02 MiB | 33.21 MiB/s, done.
# Resolving deltas: 100% (105/105), done.
# Checking out files: 100% (40/40), done.

# %% [markdown]
# # New Section

# %%
# Imports required packages, defines stem & tokenizez function

import pandas as pd
from rank_bm25 import BM25Okapi
import nltk
from nltk.stem.porter import PorterStemmer

nltk.download('punkt')
nltk.download('stopwords')

def stem_tokenize(text, remove_stopwords=True):
  stemmer = PorterStemmer()
  tokens = [word for sent in nltk.sent_tokenize(text) \
                                      for word in nltk.word_tokenize(sent)]
  tokens = [word for word in tokens if word not in \
          nltk.corpus.stopwords.words('english')]
  return [stemmer.stem(word) for word in tokens]
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# Files paths

request_file_path = './ClariQ-repo/data/dev.tsv'
question_bank_path = './ClariQ-repo/data/question_bank.tsv'
run_file_path = './ClariQ-repo/sample_runs/dev_bm25'

# %%
# Reads files and build bm25 corpus (index)

dev = pd.read_csv(request_file_path, sep='\t')
question_bank = pd.read_csv(question_bank_path, sep='\t').fillna('')

question_bank['tokenized_question_list'] = question_bank['question'].map(stem_tokenize)
question_bank['tokenized_question_str'] = question_bank['tokenized_question_list'].map(lambda x: ' '.join(x))

bm25_corpus = question_bank['tokenized_question_list'].tolist()
bm25 = BM25Okapi(bm25_corpus)

# %%
dev
# Out:
#       topic_id                                             initial_request  \
# 0          101  Find me information about the Ritz Carlton Lake Las Vegas.
# 1          101  Find me information about the Ritz Carlton Lake Las Vegas.
# 2          101  Find me information about the Ritz Carlton Lake Las Vegas.
# 3          101  Find me information about the Ritz Carlton Lake Las Vegas.
# 4          101  Find me information about the Ritz Carlton Lake Las Vegas.
# ...        ...                                                         ...
# 2308       292  i'm interested in history of the electronic medical record
# 2309       292  i'm interested in history of the electronic medical record
# 2310       292  i'm interested in history of the electronic medical record
# 2311       292  i'm interested in history of the electronic medical record
# 2312       292  i'm interested in history of the electronic medical record
#
#                                                                                                               topic_desc  \
# 0                                                      Find information about the Ritz Carlton resort at Lake Las Vegas.
# 1                                                      Find information about the Ritz Carlton resort at Lake Las Vegas.
# 2                                                      Find information about the Ritz Carlton resort at Lake Las Vegas.
# 3                                                      Find information about the Ritz Carlton resort at Lake Las Vegas.
# 4                                                      Find information about the Ritz Carlton resort at Lake Las Vegas.
# ...                                                                                                                  ...
# 2308  Find information on how the electronic medical record (or electronic health record) has evolved through the years.
# 2309  Find information on how the electronic medical record (or electronic health record) has evolved through the years.
# 2310  Find information on how the electronic medical record (or electronic health record) has evolved through the years.
# 2311  Find information on how the electronic medical record (or electronic health record) has evolved through the years.
# 2312  Find information on how the electronic medical record (or electronic health record) has evolved through the years.
#
#       clarification_need facet_id  \
# 0                      2    F0010
# 1                      2    F0010
# 2                      2    F0010
# 3                      2    F0010
# 4                      2    F0010
# ...                  ...      ...
# 2308                   3    F0745
# 2309                   3    F0745
# 2310                   3    F0745
# 2311                   3    F0745
# 2312                   3    F0745
#
#                                                                                                               facet_desc  \
# 0                                                      Find information about the Ritz Carlton resort at Lake Las Vegas.
# 1                                                      Find information about the Ritz Carlton resort at Lake Las Vegas.
# 2                                                      Find information about the Ritz Carlton resort at Lake Las Vegas.
# 3                                                      Find information about the Ritz Carlton resort at Lake Las Vegas.
# 4                                                      Find information about the Ritz Carlton resort at Lake Las Vegas.
# ...                                                                                                                  ...
# 2308  Find information on how the electronic medical record (or electronic health record) has evolved through the years.
# 2309  Find information on how the electronic medical record (or electronic health record) has evolved through the years.
# 2310  Find information on how the electronic medical record (or electronic health record) has evolved through the years.
# 2311  Find information on how the electronic medical record (or electronic health record) has evolved through the years.
# 2312  Find information on how the electronic medical record (or electronic health record) has evolved through the years.
#
#      question_id  \
# 0         Q00697
# 1         Q03272
# 2         Q03282
# 3         Q03582
# 4         Q03695
# ...          ...
# 2308      Q02038
# 2309      Q02314
# 2310      Q03305
# 2311      Q03679
# 2312      Q03724
#
#                                                                                question  \
# 0                                               are you looking for a specific web site
# 1                             would you like the history of ritz carlton lake las vegas
# 2                        would you like the location of the ritz carlton lake las vegas
# 3                    would you like to know the capacity of ritz carlton lake las vegas
# 4                  would you like to know where ritz carlton lake las vegas is on a map
# ...                                                                                 ...
# 2308                    do you want to know how electronic medical record keeping began
# 2309                       do you want to know when the first medical record was record
# 2310                                      would you like to buy a book about this topic
# 2311  would you like to know when the electronic medical record became more widely used
# 2312                  would you like to know who invented the electronic medical record
#
#                                                                    answer
# 0                       yes for the ritz carlton resort at lake las vegas
# 1       where can i find the history of the ritz carton lake in las vegas
# 2                                        yes along with other information
# 3                                               yes and other information
# 4     no i want to know more about the ritz carlton lake las vegas resort
# ...                                                                   ...
# 2308                                    yes and the evolution there after
# 2309                                                      that would help
# 2310                                         no show me the history of it
# 2311                  i would like to know how its evolved over the years
# 2312                                       just a timeline of it evolving
#
# [2313 rows x 9 columns]

# %%
question_bank
# Out:
#      question_id                                           question  \
# 0         Q00001
# 1         Q00002  a total cholesterol of 180 to 200 mgdl 10 to 1...
# 2         Q00003  about how many years experience do you want th...
# 3         Q00004  according to anima the bible or what other source
# 4         Q00005  ae you looking for examples of septic system d...
# ...          ...                                                ...
# 3936      Q03937        would you want to buy flame design stickers
# 3937      Q03938  would you want to know about ron howards actin...
# 3938      Q03939        would you want to know credit report scores
# 3939      Q03940  would you want to know what is in a credit report
# 3940      Q03941        would you wanting to know how to set one up
#
#                                 tokenized_question_list  \
# 0                                                    []
# 1     [total, cholesterol, 180, 200, mgdl, 10, 111, ...
# 2                [mani, year, experi, want, instructor]
# 3                          [accord, anima, bibl, sourc]
# 4            [ae, look, exampl, septic, system, design]
# ...                                                 ...
# 3936         [would, want, buy, flame, design, sticker]
# 3937      [would, want, know, ron, howard, act, career]
# 3938         [would, want, know, credit, report, score]
# 3939                [would, want, know, credit, report]
# 3940                      [would, want, know, set, one]
#
#                                  tokenized_question_str
# 0
# 1     total cholesterol 180 200 mgdl 10 111 mmoll le...
# 2                      mani year experi want instructor
# 3                               accord anima bibl sourc
# 4                   ae look exampl septic system design
# ...                                                 ...
# 3936                would want buy flame design sticker
# 3937              would want know ron howard act career
# 3938                would want know credit report score
# 3939                      would want know credit report
# 3940                            would want know set one
#
# [3941 rows x 4 columns]

# %%
# Runs bm25 for every query and stores output in file.

queries = []
clarifying_questions = []

with open(run_file_path, 'w') as fo:
  for tid in dev['topic_id'].unique():
    query = dev.loc[dev['topic_id']==tid, 'initial_request'].tolist()[0]
    bm25_ranked_list = bm25.get_top_n(stem_tokenize(query, True), 
                                    bm25_corpus, 
                                    n=30)
    bm25_q_list = [' '.join(sent) for sent in bm25_ranked_list]
    preds = question_bank.set_index('tokenized_question_str').loc[bm25_q_list, 'question_id'].tolist()
    queries.append(query)
    clarifying_questions.append(question_bank.loc[question_bank['question_id'] == preds[0], 'question'].tolist()[0])
    for i, qid in enumerate(preds):    
      fo.write('{} 0 {} {} {} bm25\n'.format(tid, qid, i, len(preds)-i))

# %%
pd.set_option('max_colwidth', 300)
pd.DataFrame({"query": queries, "clarifying question": clarifying_questions})
# Out:
#                                                                             query  \
# 0                      Find me information about the Ritz Carlton Lake Las Vegas.
# 1                                   I'm looking for universal animal cuts reviews
# 2                                              tell me about cass county missouri
# 3                                               Tell about an adobe indian house?
# 4                                                 What is von Willebrand Disease?
# 5                                           Tell me about atypical squamous cells
# 6                                                       all men are created equal
# 7                                          Tell me more about Rocky Mountain News
# 8                            Find me information about the sales tax in Illinois.
# 9                                     I'm looking for information on hobby stores
# 10                                      I’m looking for blue throated hummingbird
# 11                                Tell me information about computer programming.
# 12                                         What should I know about the civil war
# 13                                                I want to learn about rock art.
# 14                                    I'm looking for a wedding budget calculator
# 15                                                Find Brooks Brothers clearance.
# 16                                                  When can I see Churchil Downs
# 17                                         Where should I order dog clean-up bags
# 18                                              Where can I buy pressure washers?
# 19                                Find information on ontario california airport.
# 20                                                        tell me about diversity
# 21                                                      Tell me more about Euclid
# 22                                                       Tell me about Starbucks.
# 23                                                    Find information on Hoboken
# 24                                                    Tell me about pampered chef
# 25                                           Give me information on solar panels.
# 26                                        Find information about living in India.
# 27                                                             Tell me about kiwi
# 28                                               I want to know about appraisals.
# 29                          Find information from the milwaukee journal sentinel.
# 30  What does the US capital gains tax rate consist of and how is it broken down?
# 31                                     What was the name of Elvis Presley's home?
# 32                                                 Fine me beef stroganoff recipe
# 33                                              What are problems with ford edge?
# 34                                          Tell me about history of orcas island
# 35                                      Find more information about baldness cure
# 36                                             Find information on hayrides in pa
# 37                             What are treatments for carotid cavernous fistula?
# 38           Tell me about the educational advantages of social networking sites.
# 39                                        where to go if I made a crime in Brazil
# 40                                               What is Poem in Your Pocket Day?
# 41                                                Find me a map of the US Capitol
# 42                                                  How to cure angular cheilitis
# 43                                                         Tell me about defender
# 44                                                             Find me map of USA
# 45                                                Tell me more about horse hooves
# 46                                                          tell me about Voyager
# 47                                                           tell me about memory
# 48                                     Who is the patron saint of mental illness?
# 49                     i'm interested in history of the electronic medical record
#
#                                                                                      clarifying question
# 0                                  do you want historical information on the ritz carlton lake las vegas
# 1                                                         would you like to review universal animal cuts
# 2                                          do you want to know about the schools in cass county missouri
# 3                                                      are you looking for a tour of adobe indian houses
# 4                                              are you interested in the types of von willebrand disease
# 5                                                 are you interested in atypical squamous cells in urine
# 6                                                                          when was raspberry pi created
# 7                                     are you looking for information regarding the rocky mountain range
# 8                                               are you interested in how to pay your illinois state tax
# 9                                                             are you looking for a specific hobby store
# 10                            are you interested in learning about where blue throated hummingbirds live
# 11                                 do you any specific information about computer science degree program
# 12                                                            are you looking for the american civil war
# 13                                                                     do you want locations of rock art
# 14                                                       are you looking for advice on wedding budgeting
# 15                                                are you trying to find brooks brothers clearance suits
# 16                                                            are you wondering where churchill downs is
# 17                                                   are you looking for biodegradable dog clean up bags
# 18                                                              are you looking to buy a pressure washer
# 19                                             are you interested in visiting ontario california airport
# 20                                                             what can i tell you about wilsons disease
# 21                                                                  do you need directions to euclid ave
# 22                                                             what can i tell you about wilsons disease
# 23                                                     do you want information on the climate of hoboken
# 24                                                         are you wondering the prices of pampered chef
# 25                             are you looking for information on purchasing and installing solar panels
# 26                               would you like more information about the challenges of living in india
# 27                                                             what can i tell you about wilsons disease
# 28                                                          do you want to know the cost of an appraisal
# 29                                are you interested in a subscription to the milwaukee journal sentinel
# 30                                             which of the capital gains tax rate are you interested in
# 31                                                     are you interested in touring elvis presleys home
# 32                                                  what would you like to make with the beef stroganoff
# 33                                          what year is the ford edge that you are having problems with
# 34                                             are you interested in proeuropean history of orcas island
# 35                                                          are you interested in a natural balding cure
# 36                                                             what type of hayrides are you looking for
# 37                                                                     what is carotid cavernous fistula
# 38                            what type of educational advantages are you seeking from social networking
# 39                                                                    when are you going to the pococnos
# 40                                                  did you want to know when poem in your pocket day is
# 41                                                            do you want a state capitol map for the us
# 42                                                        have you been diagnosed with angular cheilitis
# 43                                                                   are you looking for defender lyrics
# 44                                                                can i help you find something on a map
# 45                                                   what problem is your horse having with their hooves
# 46                                                       are you referring to the voyager 1 or voyager 2
# 47                                                             what can i tell you about wilsons disease
# 48                                          why are you interested in the patron saint of mental illness
# 49  are you interested in learning about what was used before the electronic medical record was invented

# %%
# Report question relevance performance
! python ./ClariQ-repo/src/clariq_eval_tool.py  --eval_task question_relevance\
                                                --data_dir ./ClariQ-repo/data/ \
                                                --experiment_type dev \
                                                --run_file {run_file_path} \
                                                --out_file {run_file_path}_question_relevance.eval
# Out:
# Recall5: 0.3245570421150917
# Recall10: 0.5638042646208281
# Recall20: 0.6674997108155003
# Recall30: 0.6912818698329535
