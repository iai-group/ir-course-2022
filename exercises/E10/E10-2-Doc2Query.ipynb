# %% [markdown]
# # Doc2Query
#
# This demo presents the document expansion learning with Doc2Qeury. The code snippets are based on example provided along with the [PyTerrier plugin](https://github.com/terrierteam/pyterrier_doc2query) for Doc2Query. We are using here a pretrained docuement expansion model. A Doc2Query object has a *transform()* function, which takes the text of each document, and suggests questions for that text.

# %%
# %%capture
# !pip install --upgrade git+https://github.com/terrier-org/pyterrier.git#egg=python-terrier
# !pip install --upgrade git+https://github.com/terrierteam/pyterrier_doc2query.git

# %%
# %%capture
import os
if not os.path.exists("t5-base.zip"):
  # !wget https://git.uwaterloo.ca/jimmylin/doc2query-data/raw/master/T5-passage/t5-base.zip
  # !unzip t5-base.zip

# %%
import pyterrier as pt
pt.init()
# Out:
# terrier-assemblies 5.6 jar-with-dependencies not found, downloading to /root/.pyterrier...
# Done
# terrier-python-helper 0.0.6 jar not found, downloading to /root/.pyterrier...
# Done
# PyTerrier 0.8.1 has loaded Terrier 5.6 (built by craigmacdonald on 2021-09-17 13:27)

# %%
from pyterrier_doc2query import Doc2Query
import pandas as pd
doc2query = Doc2Query(out_attr="text", batch_size=8)
# Out:
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/models/t5/tokenization_t5.py:174: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   FutureWarning,
# Doc2query using cuda

# %%
sample_doc = "The presence of communication amid scientific minds was equally important to the success of the Manhattan Project as scientific intellect was. The only cloud hanging over the impressive achievement of the atomic researchers and engineers is what their success truly meant; hundreds of thousands of innocent lives obliterated"
doc2query._doc2query([sample_doc, sample_doc])
# Out:
# ['what were the major achievements of the manhattan project why did the manhattan project succeed why was it important that science was included in the manhattan project?',
#  'who helped make the manhattan project a success? why was the manhattan project important what was the purpose of the manhattan project and why did we do this']

# %%
doc2query.transform(pd.DataFrame([{'docno' : 'd1', 'text' : sample_doc}]))["text"][0]
# Out:
# 'why was the manhattan project important why was the manhattan project successful? why manhattan success'
